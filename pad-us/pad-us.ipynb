# %% [markdown]
# # PAD-US v4
#
# U.S. Geological Survey (USGS) Gap Analysis Project (GAP), 2024, Protected Areas Database of the United States (PAD-US) 4.0: U.S. Geological Survey data release, https://doi.org/10.5066/P96WBCHS.

# %%
# pip install git+https://github.com/boettiger-lab/cng-python.git

# %%
import ibis
from ibis import _
con = ibis.duckdb.connect("tmp", extensions = ["spatial"])

# s3-write permissions
from cng.utils import set_secrets, ST_MakeValid, to_geojson, to_pmtiles, s3_cp
import streamlit as st
set_secrets(con, st.secrets["MINIO_KEY"], st.secrets["MINIO_SECRET"])

#con.raw_sql("SET MEMORY_LIMIT='10G'")

# %%
from pathlib import Path
zip = "PADUS4_0_Geodatabase.zip"

if Path(zip).exists():
    import zipfile
    with zipfile.ZipFile(zip, 'r') as zip_ref:
        zip_ref.extractall()

# %%
#con.sql(f"select * from st_read_meta('{gdb}')").execute()  # no metadata?
# using duckdb + try_cast doesn't work either.
gdb = "PADUS4_0_Geodatabase.gdb"
layer = "PADUS4_0Combined_Proclamation_Marine_Fee_Designation_Easement"

fgb = "pad-us-4.fgb"

if Path(gdb).exists():
    ## UGH, duckdb still complains 'Geometry type 11 not supported'
    import geopandas
    gdf = geopandas.read_file(pad_us_4_gdb,
                layer = layer,
                driver = "pygrio")
    gdf.to_file()
    crs = gdf.crs.to_string()

# %%
# Sadly cannot do it this way
# con.read_geo(gdb, layer = layer, keep_wkb = True).mutate(geom = SHAPE.try_cast("geometry")).to_parquet('test.parquet')

# %%
# Geometry type 11 not supported
# SELECT TRY_CAST(wkb_geometry AS GEOMETRY) FROM st_read('some_dataset.fgb', keep_wkb := true);

# use fgb from geopandas instead

if Path(fgb).exists():
    (
        con
        .read_geo("pad-us-4.fgb")
        .mutate(geom = _.geom.convert('ESRI:102039', 'EPSG:4326'))
        .filter((_.FeatClass.isin(["Easement", "Fee"])) | (
            (_.FeatClass == "Proclamation") & (_.Mang_Name == "TRIB"))
            )
        .mutate(geom = ST_MakeValid(_.geom), 
                row_n = ibis.row_number())
        .to_parquet('s3://public-biodiversity/pad-us-4/pad-us-4.parquet')
    )

# %%
# crosses the antimerdian, creates issues.   
# better solution https://maplibre.org/maplibre-gl-js/docs/examples/line-across-180th-meridian/
#  https://github.com/gadomski/antimeridian
dropme = "Papahanaumokuakea Marine National Monument"
s3 = 's3://public-biodiversity/pad-us-4/pad-us-4.parquet'
parquet = con.read_parquet(s3)
parquet.filter(_.Unit_Nm != dropme).to_parquet(s3)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
# optionally select specific columns to include/exclude
parquet = con.read_parquet('s3://public-biodiversity/pad-us-4/pad-us-4.parquet')

to_geojson(parquet, "pad-us-4.geojson", con = con)
pmtiles = to_pmtiles("pad-us-4.geojson", "pad-us-4.pmtiles")

# upload, since pmtiles cannot stream to/from buckets
s3_cp('pad-us-4.pmtiles', "s3://public-biodiversity/pad-us-4/pad-us-4.pmtiles", "minio", key = st.secrets["MINIO_KEY"], secret = st.secrets["MINIO_SECRET"] )
# Note the layer name for pmtiles: 'padus4'
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# For layer 0, using name "padus4"
# 633636 features, 607180492 bytes of geometry and attributes, 45832193 bytes of string pool, 0 bytes of vertices, 0 bytes of nodes
# tile 1/0/0 size is 881403 (probably really 881403) with detail 12, >500000
# Going to try keeping the sparsest 45.38% of the features to make it fit
# tile 1/0/0 size is 826138 (probably really 826138) with detail 12, >500000
# Going to try keeping the sparsest 21.97% of the features to make it fit
# tile 1/0/0 size is 737574 (probably really 737574) with detail 12, >500000
# Going to try keeping the sparsest 11.92% of the features to make it fit
# tile 1/0/0 size is 633799 (probably really 633799) with detail 12, >500000
# Going to try keeping the sparsest 7.52% of the features to make it fit
# tile 1/0/0 size is 534715 (probably really 534715) with detail 12, >500000
# Going to try keeping the sparsest 5.63% of the features to make it fit
# tile 2/0/1 size is 1361070 (probably really 1361070) with detail 12, >500000
# Going to try keeping the sparsest 29.39% of the features to make it fit
# tile 2/1/1 size is 1006790 (probably really 1006790) with detail 12, >500000
# Going to try keeping the sparsest 39.73% of the features to make it fit
# tile 2/0/1 size is 1136052 (probably really 1136052) with detail 12, >500000
# Going to try keeping the sparsest 10.35% of the features to make it fit
# tile 2/1/1 size is 851786 (probably really 851786) with detail 12, >500000
# Going to try keeping the sparsest 18.66% of the features to make it fit
# tile 2/0/1 size is 727235 (probably really 727235) with detail 12, >500000
# Going to try keeping the sparsest 5.69% of the features to make it fit
# tile 2/1/1 size is 680386 (probably really 680386) with detail 12, >500000
# Going to try keeping the sparsest 10.97% of the features to make it fit
# tile 2/1/1 size is 561401 (probably really 561401) with detail 12, >500000
# Going to try keeping the sparsest 7.82% of the features to make it fit
# tile 2/0/1 size is 549640 (probably really 549640) with detail 12, >500000
# Going to try keeping the sparsest 4.14% of the features to make it fit
# tile 3/1/3 size is 1394782 (probably really 1394782) with detail 12, >500000
# Going to try keeping the sparsest 28.68% of the features to make it fit
# tile 3/1/2 size is 1829509 (probably really 1829509) with detail 12, >500000
# Going to try keeping the sparsest 21.86% of the features to make it fit
# tile 3/2/2 size is 1281544 (probably really 1281544) with detail 12, >500000
# Going to try keeping the sparsest 31.21% of the features to make it fit
# tile 3/1/3 size is 1086785 (probably really 1086785) with detail 12, >500000
# Going to try keeping the sparsest 10.56% of the features to make it fit
# tile 3/1/2 size is 1122176 (probably really 1122176) with detail 12, >500000
# Going to try keeping the sparsest 7.79% of the features to make it fit
# tile 3/2/2 size is 879110 (probably really 879110) with detail 12, >500000
# Going to try keeping the sparsest 14.20% of the features to make it fit
# tile 3/1/3 size is 633819 (probably really 633819) with detail 12, >500000
# Going to try keeping the sparsest 6.66% of the features to make it fit
# tile 3/1/2 size is 662340 (probably really 662340) with detail 12, >500000
# Going to try keeping the sparsest 4.71% of the features to make it fit
# tile 3/2/2 size is 596636 (probably really 596636) with detail 12, >500000
# Going to try keeping the sparsest 9.52% of the features to make it fit
# tile 3/2/3 size is 1640984 (probably really 1640984) with detail 12, >500000
# Going to try keeping the sparsest 24.38% of the features to make it fit
# tile 3/1/2 size is 536264 (probably really 536264) with detail 12, >500000
# Going to try keeping the sparsest 3.51% of the features to make it fit
# tile 3/2/3 size is 1033431 (probably really 1033431) with detail 12, >500000
# Going to try keeping the sparsest 9.43% of the features to make it fit
# tile 3/2/3 size is 615434 (probably really 615434) with detail 12, >500000
# Going to try keeping the sparsest 6.13% of the features to make it fit
# tile 4/2/6 size is 748327 (probably really 748327) with detail 12, >500000
# Going to try keeping the sparsest 53.45% of the features to make it fit
# tile 4/2/5 size is 743983 (probably really 743983) with detail 12, >500000
# Going to try keeping the sparsest 53.76% of the features to make it fit
# tile 4/2/6 size is 711569 (probably really 711569) with detail 12, >500000
# Going to try keeping the sparsest 30.05% of the features to make it fit
# tile 4/2/5 size is 691825 (probably really 691825) with detail 12, >500000
# Going to try keeping the sparsest 31.09% of the features to make it fit
# tile 4/3/5 size is 2664227 (probably really 2664227) with detail 12, >500000
# Going to try keeping the sparsest 15.01% of the features to make it fit
# tile 4/3/6 size is 1834268 (probably really 1834268) with detail 12, >500000
# Going to try keeping the sparsest 21.81% of the features to make it fit
# tile 4/2/6 size is 609329 (probably really 609329) with detail 12, >500000
# Going to try keeping the sparsest 19.73% of the features to make it fit
# tile 4/2/5 size is 582227 (probably really 582227) with detail 12, >500000
# Going to try keeping the sparsest 21.36% of the features to make it fit
# tile 4/2/6 size is 509000 (probably really 509000) with detail 12, >500000
# Going to try keeping the sparsest 15.50% of the features to make it fit
# tile 4/3/5 size is 1065334 (probably really 1065334) with detail 12, >500000
# Going to try keeping the sparsest 5.64% of the features to make it fit
# tile 4/2/5 size is 508684 (probably really 508684) with detail 12, >500000
# Going to try keeping the sparsest 16.79% of the features to make it fit
# tile 4/3/6 size is 1049393 (probably really 1049393) with detail 12, >500000
# Going to try keeping the sparsest 8.31% of the features to make it fit
# tile 4/4/5 size is 2923143 (probably really 2923143) with detail 12, >500000
# Going to try keeping the sparsest 13.68% of the features to make it fit
# tile 4/3/5 size is 642390 (probably really 642390) with detail 12, >500000
# Going to try keeping the sparsest 3.51% of the features to make it fit
# tile 4/3/6 size is 633497 (probably really 633497) with detail 12, >500000
# Going to try keeping the sparsest 5.25% of the features to make it fit
# tile 4/3/5 size is 507450 (probably really 507450) with detail 12, >500000
# Going to try keeping the sparsest 2.77% of the features to make it fit
# tile 4/4/5 size is 1011287 (probably really 1011287) with detail 12, >500000
# Going to try keeping the sparsest 5.41% of the features to make it fit
# tile 4/3/6 size is 517048 (probably really 517048) with detail 12, >500000
# Going to try keeping the sparsest 4.06% of the features to make it fit
# tile 4/4/5 size is 535306 (probably really 535306) with detail 12, >500000
# Going to try keeping the sparsest 4.04% of the features to make it fit
# tile 4/4/6 size is 3746045 (probably really 3746045) with detail 12, >500000
# Going to try keeping the sparsest 10.68% of the features to make it fit
# tile 4/4/6 size is 1133776 (probably really 1133776) with detail 12, >500000
# Going to try keeping the sparsest 3.77% of the features to make it fit
# tile 4/4/6 size is 530152 (probably really 530152) with detail 12, >500000
# Going to try keeping the sparsest 2.84% of the features to make it fit
# tile 5/7/12 size is 983737 (probably really 983737) with detail 12, >500000
# Going to try keeping the sparsest 40.66% of the features to make it fit
# tile 5/7/12 size is 657708 (probably really 657708) with detail 12, >500000
# Going to try keeping the sparsest 24.73% of the features to make it fit
# tile 5/8/11 size is 1403162 (probably really 1403162) with detail 12, >500000
# Going to try keeping the sparsest 28.51% of the features to make it fit
# tile 5/8/11 size is 694037 (probably really 694037) with detail 12, >500000
# Going to try keeping the sparsest 16.43% of the features to make it fit
# tile 5/6/11 size is 1678683 (probably really 1678683) with detail 12, >500000
# Going to try keeping the sparsest 23.83% of the features to make it fit
# tile 5/5/12 size is 1153392 (probably really 1153392) with detail 12, >500000
# Going to try keeping the sparsest 34.68% of the features to make it fit
# tile 5/5/11 size is 1129784 (probably really 1129784) with detail 12, >500000
# Going to try keeping the sparsest 35.40% of the features to make it fit
# tile 5/6/12 size is 1451740 (probably really 1451740) with detail 12, >500000
# Going to try keeping the sparsest 27.55% of the features to make it fit
# tile 5/7/11 size is 2429606 (probably really 2429606) with detail 12, >500000
# Going to try keeping the sparsest 16.46% of the features to make it fit
# tile 5/6/11 size is 794964 (probably really 794964) with detail 12, >500000
# Going to try keeping the sparsest 11.99% of the features to make it fit
# tile 5/5/12 size is 887923 (probably really 887923) with detail 12, >500000
# Going to try keeping the sparsest 15.62% of the features to make it fit
# tile 5/7/11 size is 843380 (probably really 843380) with detail 12, >500000
# Going to try keeping the sparsest 7.81% of the features to make it fit
# tile 5/5/11 size is 859797 (probably really 859797) with detail 12, >500000
# Going to try keeping the sparsest 16.47% of the features to make it fit
# tile 5/6/12 size is 875084 (probably really 875084) with detail 12, >500000
# Going to try keeping the sparsest 12.59% of the features to make it fit
# tile 5/8/12 size is 2308986 (probably really 2308986) with detail 12, >500000
# Going to try keeping the sparsest 17.32% of the features to make it fit
# tile 5/6/11 size is 596264 (probably really 596264) with detail 12, >500000
# Going to try keeping the sparsest 8.04% of the features to make it fit
# tile 5/7/11 size is 527978 (probably really 527978) with detail 12, >500000
# Going to try keeping the sparsest 5.92% of the features to make it fit
# tile 5/5/12 size is 620409 (probably really 620409) with detail 12, >500000
# Going to try keeping the sparsest 10.07% of the features to make it fit
# tile 5/5/11 size is 648472 (probably really 648472) with detail 12, >500000
# Going to try keeping the sparsest 10.16% of the features to make it fit
# tile 5/6/12 size is 633436 (probably really 633436) with detail 12, >500000
# Going to try keeping the sparsest 7.95% of the features to make it fit
# tile 5/6/11 size is 520776 (probably really 520776) with detail 12, >500000
# Going to try keeping the sparsest 6.18% of the features to make it fit
# tile 5/8/12 size is 788462 (probably really 788462) with detail 12, >500000
# Going to try keeping the sparsest 8.79% of the features to make it fit
# tile 5/5/12 size is 512002 (probably really 512002) with detail 12, >500000
# Going to try keeping the sparsest 7.87% of the features to make it fit
# tile 5/9/11 size is 4261466 (probably really 4261466) with detail 12, >500000
# Going to try keeping the sparsest 9.39% of the features to make it fit
# tile 5/5/11 size is 565237 (probably really 565237) with detail 12, >500000
# Going to try keeping the sparsest 7.19% of the features to make it fit
# tile 5/6/12 size is 545213 (probably really 545213) with detail 12, >500000
# Going to try keeping the sparsest 5.83% of the features to make it fit
# tile 5/5/11 size is 521406 (probably really 521406) with detail 12, >500000
# Going to try keeping the sparsest 5.52% of the features to make it fit
# tile 5/9/11 size is 877462 (probably really 877462) with detail 12, >500000
# Going to try keeping the sparsest 4.28% of the features to make it fit
# tile 5/9/12 size is 4441205 (probably really 4441205) with detail 12, >500000
# Going to try keeping the sparsest 9.01% of the features to make it fit
# tile 5/6/12 size is 502610 (probably really 502610) with detail 12, >500000
# Going to try keeping the sparsest 4.64% of the features to make it fit
# tile 5/9/12 size is 820504 (probably really 820504) with detail 12, >500000
# Going to try keeping the sparsest 4.39% of the features to make it fit
# tile 6/15/24 size is 509962 (probably really 509962) with detail 12, >500000
# Going to try keeping the sparsest 78.44% of the features to make it fit
# tile 6/14/23 size is 624232 (probably really 624232) with detail 12, >500000
# Going to try keeping the sparsest 64.08% of the features to make it fit
# tile 6/13/23 size is 726218 (probably really 726218) with detail 12, >500000
# Going to try keeping the sparsest 55.08% of the features to make it fit
# tile 6/17/23 size is 691475 (probably really 691475) with detail 12, >500000
# Going to try keeping the sparsest 57.85% of the features to make it fit
# tile 6/14/22 size is 1029434 (probably really 1029434) with detail 12, >500000
# Going to try keeping the sparsest 38.86% of the features to make it fit
# tile 6/15/23 size is 905604 (probably really 905604) with detail 12, >500000
# Going to try keeping the sparsest 44.17% of the features to make it fit
# tile 6/16/23 size is 1053558 (probably really 1053558) with detail 12, >500000
# Going to try keeping the sparsest 37.97% of the features to make it fit
# tile 6/16/24 size is 694991 (probably really 694991) with detail 12, >500000
# Going to try keeping the sparsest 57.55% of the features to make it fit
# tile 6/17/23 size is 518999 (probably really 518999) with detail 12, >500000
# Going to try keeping the sparsest 44.58% of the features to make it fit
# tile 6/12/23 size is 768416 (probably really 768416) with detail 12, >500000
# Going to try keeping the sparsest 52.06% of the features to make it fit
# tile 6/12/24 size is 654298 (probably really 654298) with detail 12, >500000
# Going to try keeping the sparsest 61.13% of the features to make it fit
# tile 6/16/25 size is 561334 (probably really 561334) with detail 12, >500000
# Going to try keeping the sparsest 71.26% of the features to make it fit
# tile 6/13/24 size is 839018 (probably really 839018) with detail 12, >500000
# Going to try keeping the sparsest 47.67% of the features to make it fit
# tile 6/10/22 size is 669722 (probably really 669722) with detail 12, >500000
# Going to try keeping the sparsest 59.73% of the features to make it fit
# tile 6/15/23 size is 545834 (probably really 545834) with detail 12, >500000
# Going to try keeping the sparsest 32.37% of the features to make it fit
# tile 6/14/22 size is 514932 (probably really 514932) with detail 12, >500000
# Going to try keeping the sparsest 30.18% of the features to make it fit
# tile 6/10/24 size is 796589 (probably really 796589) with detail 12, >500000
# Going to try keeping the sparsest 50.21% of the features to make it fit
# tile 6/15/22 size is 763688 (probably really 763688) with detail 12, >500000
# Going to try keeping the sparsest 52.38% of the features to make it fit
# tile 6/16/23 size is 587788 (probably really 587788) with detail 12, >500000
# Going to try keeping the sparsest 25.84% of the features to make it fit
# tile 6/16/24 size is 505705 (probably really 505705) with detail 12, >500000
# Going to try keeping the sparsest 45.52% of the features to make it fit
# tile 6/11/25 size is 526705 (probably really 526705) with detail 12, >500000
# Going to try keeping the sparsest 75.94% of the features to make it fit
# tile 6/17/24 size is 1127872 (probably really 1127872) with detail 12, >500000
# Going to try keeping the sparsest 35.47% of the features to make it fit
# tile 6/13/24 size is 568003 (probably really 568003) with detail 12, >500000
# Going to try keeping the sparsest 33.57% of the features to make it fit
# tile 6/12/23 size is 508666 (probably really 508666) with detail 12, >500000
# Going to try keeping the sparsest 40.93% of the features to make it fit
# tile 6/12/24 size is 505914 (probably really 505914) with detail 12, >500000
# Going to try keeping the sparsest 48.34% of the features to make it fit
# tile 6/10/22 size is 546545 (probably really 546545) with detail 12, >500000
# Going to try keeping the sparsest 43.71% of the features to make it fit
# tile 6/10/24 size is 619729 (probably really 619729) with detail 12, >500000
# Going to try keeping the sparsest 32.41% of the features to make it fit
# tile 6/17/25 size is 1035523 (probably really 1035523) with detail 12, >500000
# Going to try keeping the sparsest 38.63% of the features to make it fit
# tile 6/15/22 size is 562456 (probably really 562456) with detail 12, >500000
# Going to try keeping the sparsest 37.25% of the features to make it fit
# tile 6/17/24 size is 586523 (probably really 586523) with detail 12, >500000
# Going to try keeping the sparsest 24.19% of the features to make it fit
# tile 6/11/25 size is 511307 (probably really 511307) with detail 12, >500000
# Going to try keeping the sparsest 59.41% of the features to make it fit
# tile 6/17/25 size is 606517 (probably really 606517) with detail 12, >500000
# Going to try keeping the sparsest 25.48% of the features to make it fit
# tile 6/18/23 size is 2187129 (probably really 2187129) with detail 12, >500000
# Going to try keeping the sparsest 18.29% of the features to make it fit
# tile 6/18/23 size is 681002 (probably really 681002) with detail 12, >500000
# Going to try keeping the sparsest 10.74% of the features to make it fit
# tile 6/19/23 size is 4490953 (probably really 4490953) with detail 12, >500000
# Going to try keeping the sparsest 8.91% of the features to make it fit
# tile 6/19/23 size is 707711 (probably really 707711) with detail 12, >500000
# Going to try keeping the sparsest 5.03% of the features to make it fit
# tile 6/18/24 size is 5966281 (probably really 5966281) with detail 12, >500000
# Going to try keeping the sparsest 6.70% of the features to make it fit
# tile 6/18/24 size is 833499 (probably really 833499) with detail 12, >500000
# Going to try keeping the sparsest 3.22% of the features to make it fit
# tile 7/30/46 size is 538053 (probably really 538053) with detail 12, >500000
# Going to try keeping the sparsest 74.34% of the features to make it fit
# tile 7/39/46 size is 520956 (probably really 520956) with detail 12, >500000
# Going to try keeping the sparsest 76.78% of the features to make it fit
# tile 7/20/49 size is 605608 (probably really 605608) with detail 12, >500000
# Going to try keeping the sparsest 66.05% of the features to make it fit
# tile 7/37/46 size is 617259 (probably really 617259) with detail 12, >500000
# Going to try keeping the sparsest 64.80% of the features to make it fit
# tile 7/32/47 size is 700577 (probably really 700577) with detail 12, >500000
# Going to try keeping the sparsest 57.10% of the features to make it fit
# tile 7/35/50 size is 515342 (probably really 515342) with detail 12, >500000
# Going to try keeping the sparsest 77.62% of the features to make it fit
# tile 7/26/48 size is 729780 (probably really 729780) with detail 12, >500000
# Going to try keeping the sparsest 54.81% of the features to make it fit
# tile 7/22/51 size is 596382 (probably really 596382) with detail 12, >500000
# Going to try keeping the sparsest 67.07% of the features to make it fit
# tile 7/26/48 size is 500416 (probably really 500416) with detail 12, >500000
# Going to try keeping the sparsest 43.81% of the features to make it fit
# tile 7/22/51 size is 527145 (probably really 527145) with detail 12, >500000
# Going to try keeping the sparsest 50.89% of the features to make it fit
# tile 7/36/49 size is 1183887 (probably really 1183887) with detail 12, >500000
# Going to try keeping the sparsest 33.79% of the features to make it fit
# tile 7/37/47 size is 1611169 (probably really 1611169) with detail 12, >500000
# Going to try keeping the sparsest 24.83% of the features to make it fit
# tile 7/38/46 size is 1618701 (probably really 1618701) with detail 12, >500000
# Going to try keeping the sparsest 24.71% of the features to make it fit
# tile 7/37/47 size is 586963 (probably really 586963) with detail 12, >500000
# Going to try keeping the sparsest 16.92% of the features to make it fit
# tile 7/38/46 size is 581430 (probably really 581430) with detail 12, >500000
# Going to try keeping the sparsest 17.00% of the features to make it fit
# tile 7/36/49 size is 647907 (probably really 647907) with detail 12, >500000
# Going to try keeping the sparsest 20.86% of the features to make it fit
# tile 7/36/48 size is 2976765 (probably really 2976765) with detail 12, >500000
# Going to try keeping the sparsest 13.44% of the features to make it fit
# tile 7/38/47 size is 3720834 (probably really 3720834) with detail 12, >500000
# Going to try keeping the sparsest 10.75% of the features to make it fit
# tile 7/36/48 size is 730867 (probably really 730867) with detail 12, >500000
# Going to try keeping the sparsest 7.35% of the features to make it fit
# tile 7/37/48 size is 3552329 (probably really 3552329) with detail 12, >500000
# Going to try keeping the sparsest 11.26% of the features to make it fit
# tile 7/38/47 size is 601277 (probably really 601277) with detail 12, >500000
# Going to try keeping the sparsest 7.15% of the features to make it fit
# tile 7/37/48 size is 673168 (probably really 673168) with detail 12, >500000
# Going to try keeping the sparsest 6.69% of the features to make it fit
# tile 8/77/93 size is 601959 (probably really 601959) with detail 12, >500000
# Going to try keeping the sparsest 66.45% of the features to make it fit
# tile 8/76/93 size is 555280 (probably really 555280) with detail 12, >500000
# Going to try keeping the sparsest 72.04% of the features to make it fit
# tile 8/72/97 size is 608065 (probably really 608065) with detail 12, >500000
# Going to try keeping the sparsest 65.78% of the features to make it fit
# tile 8/77/95 size is 884521 (probably really 884521) with detail 12, >500000
# Going to try keeping the sparsest 45.22% of the features to make it fit
# tile 8/76/92 size is 526253 (probably really 526253) with detail 12, >500000
# Going to try keeping the sparsest 76.01% of the features to make it fit
# tile 8/75/96 size is 776401 (probably really 776401) with detail 12, >500000
# Going to try keeping the sparsest 51.52% of the features to make it fit
# tile 8/75/95 size is 895352 (probably really 895352) with detail 12, >500000
# Going to try keeping the sparsest 44.68% of the features to make it fit
# tile 8/76/95 size is 1010508 (probably really 1010508) with detail 12, >500000
# Going to try keeping the sparsest 39.58% of the features to make it fit
# tile 8/76/94 size is 1226873 (probably really 1226873) with detail 12, >500000
# Going to try keeping the sparsest 32.60% of the features to make it fit
# tile 8/73/96 size is 963222 (probably really 963222) with detail 12, >500000
# Going to try keeping the sparsest 41.53% of the features to make it fit
# tile 8/75/95 size is 501937 (probably really 501937) with detail 12, >500000
# Going to try keeping the sparsest 35.60% of the features to make it fit
# tile 8/75/96 size is 528851 (probably really 528851) with detail 12, >500000
# Going to try keeping the sparsest 38.97% of the features to make it fit
# tile 8/76/94 size is 505477 (probably really 505477) with detail 12, >500000
# Going to try keeping the sparsest 25.80% of the features to make it fit
# tile 8/73/98 size is 762323 (probably really 762323) with detail 12, >500000
# Going to try keeping the sparsest 52.47% of the features to make it fit
# tile 8/77/94 size is 1474317 (probably really 1474317) with detail 12, >500000
# Going to try keeping the sparsest 27.13% of the features to make it fit
# tile 8/74/97 size is 1327860 (probably really 1327860) with detail 12, >500000
# Going to try keeping the sparsest 30.12% of the features to make it fit
# tile 8/73/98 size is 548327 (probably really 548327) with detail 12, >500000
# Going to try keeping the sparsest 38.28% of the features to make it fit
# tile 8/77/94 size is 514737 (probably really 514737) with detail 12, >500000
# Going to try keeping the sparsest 21.08% of the features to make it fit
# tile 8/74/97 size is 557207 (probably really 557207) with detail 12, >500000
# Going to try keeping the sparsest 21.62% of the features to make it fit
# tile 8/73/97 size is 2025023 (probably really 2025023) with detail 12, >500000
# Going to try keeping the sparsest 19.75% of the features to make it fit
# tile 8/74/96 size is 2199370 (probably really 2199370) with detail 12, >500000
# Going to try keeping the sparsest 18.19% of the features to make it fit
# tile 8/74/96 size is 584548 (probably really 584548) with detail 12, >500000
# Going to try keeping the sparsest 12.45% of the features to make it fit
# tile 8/73/97 size is 662681 (probably really 662681) with detail 12, >500000
# Going to try keeping the sparsest 11.92% of the features to make it fit
# tile 9/147/193 size is 525516 (probably really 525516) with detail 12, >500000
# Going to try keeping the sparsest 76.12% of the features to make it fit
# tile 9/154/189 size is 780625 (probably really 780625) with detail 12, >500000
# Going to try keeping the sparsest 51.24% of the features to make it fit
# tile 9/146/196 size is 593813 (probably really 593813) with detail 12, >500000
# Going to try keeping the sparsest 67.36% of the features to make it fit
# tile 9/146/194 size is 586010 (probably really 586010) with detail 12, >500000
# Going to try keeping the sparsest 68.26% of the features to make it fit
# tile 9/147/194 size is 537154 (probably really 537154) with detail 12, >500000
# Going to try keeping the sparsest 74.47% of the features to make it fit
# tile 9/149/192 size is 626607 (probably really 626607) with detail 12, >500000
# Going to try keeping the sparsest 63.84% of the features to make it fit
# tile 9/149/193 size is 712848 (probably really 712848) with detail 12, >500000
# Going to try keeping the sparsest 56.11% of the features to make it fit
# tile 9/148/194 size is 648781 (probably really 648781) with detail 12, >500000
# Going to try keeping the sparsest 61.65% of the features to make it fit
# tile 9/148/193 size is 726977 (probably really 726977) with detail 12, >500000
# Going to try keeping the sparsest 55.02% of the features to make it fit
# tile 9/146/195 size is 1138907 (probably really 1138907) with detail 12, >500000
# Going to try keeping the sparsest 35.12% of the features to make it fit
# tile 9/146/195 size is 561057 (probably really 561057) with detail 12, >500000
# Going to try keeping the sparsest 25.04% of the features to make it fit
#   99.9%  12/1086/1480
#   100.0%  12/4033/1341
# Successfully generated PMTiles file: pad-us-4.pmtiles

# %%
parquet
# Out:
# DatabaseTable: ibis_read_parquet_tirbyuisvveo5k3sx43izrlehu
#   FeatClass    string
#   Category     string
#   Own_Type     string
#   Own_Name     string
#   Loc_Own      string
#   Mang_Type    string
#   Mang_Name    string
#   Loc_Mang     string
#   Des_Tp       string
#   Loc_Ds       string
#   Unit_Nm      string
#   Loc_Nm       string
#   State_Nm     string
#   Agg_Src      string
#   GIS_Src      string
#   Src_Date     string
#   GIS_Acres    int64
#   Source_PAID  string
#   WDPA_Cd      int64
#   Pub_Access   string
#   Access_Src   string
#   Access_Dt    string
#   GAP_Sts      string
#   GAPCdSrc     string
#   GAPCdDt      string
#   IUCN_Cat     string
#   IUCNCtSrc    string
#   IUCNCtDt     string
#   Date_Est     string
#   Comments     string
#   EsmtHldr     string
#   EHoldTyp     string
#   SHAPE_Length float64
#   SHAPE_Area   float64
#   geom         geospatial:geometry
#   row_n        int64

# %%
# We can also compute intersections

"https://data.source.coop/cboettig/social-vulnerability/2022/SVI2022_US_tract.parquet"
svi = "s3://public-data/social-vulnerability/2022/SVI2022_US_tract.parquet" # faster with local

t1 = con.read_parquet(svi).select(_.ST_ABBR, _.STATE, _.COUNTY, _.FIPS, _.RPL_THEMES,  _.Shape, _.Shape_Area).rename(geom = "Shape")
t2 = con.read_parquet('s3://public-biodiversity/pad-us-4/pad-us-4.parquet').select(_.Unit_Nm, _.geom)

# %%
(t1
 .left_join(t2, t1.geom.intersects(t2.geom))
 .to_parquet("s3://public-biodiversity/pad-us-4/pad-by-tract.parquet")
)

# %%
(t1
 .right_join(t2, t1.geom.intersects(t2.geom))
 .to_parquet("s3://public-biodiversity/pad-us-4/tract-by-pad.parquet")
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# CPU times: user 18h 32min 3s, sys: 21.7 s, total: 18h 32min 24s
# Wall time: 9h 16min 32s

# %%
t1.count().execute(), t2.count().execute()
# Out:
# (84120, 414767)

# %%
# use ST number to get congressional districts
# https://www2.census.gov/geo/tiger/TIGER2024/CD/tl_2024_56_cd119.zip
