# %% [markdown]
# # PAD-US v4
#
# U.S. Geological Survey (USGS) Gap Analysis Project (GAP), 2024, Protected Areas Database of the United States (PAD-US) 4.0: U.S. Geological Survey data release, https://doi.org/10.5066/P96WBCHS.

# %%
# pip install git+https://github.com/boettiger-lab/cng-python.git

# %%
import ibis
from ibis import _
con = ibis.duckdb.connect("tmp", extensions = ["spatial"])

# s3-write permissions
from cng.utils import set_secrets, ST_MakeValid, to_geojson, to_pmtiles, s3_cp
import streamlit as st
set_secrets(con, st.secrets["MINIO_KEY"], st.secrets["MINIO_SECRET"])

#con.raw_sql("SET MEMORY_LIMIT='10G'")

# %%
from pathlib import Path
zip = "PADUS4_0_Geodatabase.zip"

if Path(zip).exists():
    import zipfile
    with zipfile.ZipFile(zip, 'r') as zip_ref:
        zip_ref.extractall()

# %%
#con.sql(f"select * from st_read_meta('{gdb}')").execute()  # no metadata?
# using duckdb + try_cast doesn't work either.
gdb = "PADUS4_0_Geodatabase.gdb"
layer = "PADUS4_0Combined_Proclamation_Marine_Fee_Designation_Easement"

fgb = "pad-us-4.fgb"

if Path(gdb).exists():
    ## UGH, duckdb still complains 'Geometry type 11 not supported'
    import geopandas
    gdf = geopandas.read_file(pad_us_4_gdb,
                layer = layer,
                driver = "pygrio")
    gdf.to_file()
    crs = gdf.crs.to_string()

# %%
# Sadly cannot do it this way
# con.read_geo(gdb, layer = layer, keep_wkb = True).mutate(geom = SHAPE.try_cast("geometry")).to_parquet('test.parquet')

# %%
# Geometry type 11 not supported
# SELECT TRY_CAST(wkb_geometry AS GEOMETRY) FROM st_read('some_dataset.fgb', keep_wkb := true);

# use fgb from geopandas instead

if Path(fgb).exists():
    (
        con
        .read_geo("pad-us-4.fgb")
        .mutate(geom = _.geom.convert('ESRI:102039', 'EPSG:4326'))
        .filter((_.FeatClass.isin(["Easement", "Fee"])) | (
            (_.FeatClass == "Proclamation") & (_.Mang_Name == "TRIB"))
            )
        .mutate(geom = ST_MakeValid(_.geom), 
                row_n = ibis.row_number())
        .to_parquet('s3://public-biodiversity/pad-us-4/pad-us-4.parquet')
    )

# %%
# optionally select specific columns to include/exclude
parquet = con.read_parquet('s3://public-biodiversity/pad-us-4/pad-us-4.parquet')

to_geojson(parquet, "pad-us-4.geojson", con = con)
pmtiles = to_pmtiles("pad-us-4.geojson", "pad-us-4.pmtiles")

# upload, since pmtiles cannot stream to/from buckets
s3_cp('pad-us-4.pmtiles', "s3://public-biodiversity/pad-us-4/pad-us-4.pmtiles", "minio")
# Note the layer name for pmtiles: 'padus4'
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# For layer 0, using name "padus4"
# 633638 features, 604694068 bytes of geometry, 45832359 bytes of string pool
# tile 1/0/0 size is 879077 with detail 12, >500000
# Going to try keeping the sparsest 51.19% of the features to make it fit
# tile 1/0/0 size is 862204 with detail 12, >500000
# Going to try keeping the sparsest 26.72% of the features to make it fit
# tile 1/0/0 size is 818349 with detail 12, >500000
# Going to try keeping the sparsest 14.69% of the features to make it fit
# tile 1/0/0 size is 734955 with detail 12, >500000
# Going to try keeping the sparsest 9.00% of the features to make it fit
# tile 1/0/0 size is 653757 with detail 12, >500000
# Going to try keeping the sparsest 6.19% of the features to make it fit
# tile 1/0/0 size is 589679 with detail 12, >500000
# Going to try keeping the sparsest 4.73% of the features to make it fit
# tile 1/0/0 size is 524356 with detail 12, >500000
# Going to try keeping the sparsest 4.06% of the features to make it fit
# tile 2/0/1 size is 1351051 with detail 12, >500000
# Going to try keeping the sparsest 33.31% of the features to make it fit
# tile 2/1/1 size is 997734 with detail 12, >500000
# Going to try keeping the sparsest 45.10% of the features to make it fit
# tile 2/0/1 size is 1202322 with detail 12, >500000
# Going to try keeping the sparsest 12.47% of the features to make it fit
# tile 2/1/1 size is 959177 with detail 12, >500000
# Going to try keeping the sparsest 21.16% of the features to make it fit
# tile 2/0/1 size is 905909 with detail 12, >500000
# Going to try keeping the sparsest 6.19% of the features to make it fit
# tile 2/1/1 size is 844215 with detail 12, >500000
# Going to try keeping the sparsest 11.28% of the features to make it fit
# tile 2/0/1 size is 692985 with detail 12, >500000
# Going to try keeping the sparsest 4.02% of the features to make it fit
# tile 2/1/1 size is 688777 with detail 12, >500000
# Going to try keeping the sparsest 7.37% of the features to make it fit
# tile 2/1/1 size is 578267 with detail 12, >500000
# Going to try keeping the sparsest 5.73% of the features to make it fit
# tile 2/0/1 size is 548630 with detail 12, >500000
# Going to try keeping the sparsest 3.30% of the features to make it fit
# tile 2/1/1 size is 515757 with detail 12, >500000
# Going to try keeping the sparsest 5.00% of the features to make it fit
# tile 3/1/3 size is 1383340 with detail 12, >500000
# Going to try keeping the sparsest 32.53% of the features to make it fit
# tile 3/1/2 size is 1814648 with detail 12, >500000
# Going to try keeping the sparsest 24.80% of the features to make it fit
# tile 3/2/2 size is 1270785 with detail 12, >500000
# Going to try keeping the sparsest 35.41% of the features to make it fit
# tile 3/1/3 size is 1205599 with detail 12, >500000
# Going to try keeping the sparsest 12.14% of the features to make it fit
# tile 3/2/2 size is 1077374 with detail 12, >500000
# Going to try keeping the sparsest 14.79% of the features to make it fit
# tile 3/1/2 size is 1196381 with detail 12, >500000
# Going to try keeping the sparsest 9.33% of the features to make it fit
# tile 3/1/3 size is 798049 with detail 12, >500000
# Going to try keeping the sparsest 6.85% of the features to make it fit
# tile 3/2/2 size is 730724 with detail 12, >500000
# Going to try keeping the sparsest 9.11% of the features to make it fit
# tile 3/1/2 size is 705135 with detail 12, >500000
# Going to try keeping the sparsest 5.95% of the features to make it fit
# tile 3/2/3 size is 1626238 with detail 12, >500000
# Going to try keeping the sparsest 27.67% of the features to make it fit
# tile 3/1/3 size is 584433 with detail 12, >500000
# Going to try keeping the sparsest 5.27% of the features to make it fit
# tile 3/2/2 size is 547978 with detail 12, >500000
# Going to try keeping the sparsest 7.48% of the features to make it fit
# tile 3/1/2 size is 541514 with detail 12, >500000
# Going to try keeping the sparsest 4.95% of the features to make it fit
# tile 3/2/3 size is 1112583 with detail 12, >500000
# Going to try keeping the sparsest 11.19% of the features to make it fit
# tile 3/2/3 size is 649937 with detail 12, >500000
# Going to try keeping the sparsest 7.75% of the features to make it fit
# tile 3/2/3 size is 510513 with detail 12, >500000
# Going to try keeping the sparsest 6.83% of the features to make it fit
# tile 4/2/6 size is 743105 with detail 12, >500000
# Going to try keeping the sparsest 60.56% of the features to make it fit
# tile 4/2/5 size is 740066 with detail 12, >500000
# Going to try keeping the sparsest 60.81% of the features to make it fit
# tile 4/2/6 size is 718624 with detail 12, >500000
# Going to try keeping the sparsest 37.92% of the features to make it fit
# tile 4/2/5 size is 708079 with detail 12, >500000
# Going to try keeping the sparsest 38.64% of the features to make it fit
# tile 4/2/6 size is 663694 with detail 12, >500000
# Going to try keeping the sparsest 25.71% of the features to make it fit
# tile 4/3/6 size is 1824722 with detail 12, >500000
# Going to try keeping the sparsest 24.66% of the features to make it fit
# tile 4/3/5 size is 2647315 with detail 12, >500000
# Going to try keeping the sparsest 17.00% of the features to make it fit
# tile 4/2/5 size is 645212 with detail 12, >500000
# Going to try keeping the sparsest 26.95% of the features to make it fit
# tile 4/2/6 size is 589104 with detail 12, >500000
# Going to try keeping the sparsest 19.64% of the features to make it fit
# tile 4/2/5 size is 571591 with detail 12, >500000
# Going to try keeping the sparsest 21.22% of the features to make it fit
# tile 4/3/5 size is 991778 with detail 12, >500000
# Going to try keeping the sparsest 7.71% of the features to make it fit
# tile 4/2/6 size is 531531 with detail 12, >500000
# Going to try keeping the sparsest 16.63% of the features to make it fit
# tile 4/3/6 size is 1197527 with detail 12, >500000
# Going to try keeping the sparsest 9.27% of the features to make it fit
# tile 4/2/5 size is 528904 with detail 12, >500000
# Going to try keeping the sparsest 18.05% of the features to make it fit
# tile 4/4/5 size is 2902297 with detail 12, >500000
# Going to try keeping the sparsest 15.50% of the features to make it fit
# tile 4/3/5 size is 564195 with detail 12, >500000
# Going to try keeping the sparsest 6.15% of the features to make it fit
# tile 4/3/6 size is 704055 with detail 12, >500000
# Going to try keeping the sparsest 5.92% of the features to make it fit
# tile 4/4/5 size is 1141168 with detail 12, >500000
# Going to try keeping the sparsest 6.11% of the features to make it fit
# tile 4/3/6 size is 500234 with detail 12, >500000
# Going to try keeping the sparsest 5.33% of the features to make it fit
# tile 4/4/5 size is 560423 with detail 12, >500000
# Going to try keeping the sparsest 4.91% of the features to make it fit
# tile 4/4/6 size is 3712403 with detail 12, >500000
# Going to try keeping the sparsest 12.12% of the features to make it fit
# tile 4/4/6 size is 944403 with detail 12, >500000
# Going to try keeping the sparsest 5.78% of the features to make it fit
# tile 4/4/6 size is 521711 with detail 12, >500000
# Going to try keeping the sparsest 4.98% of the features to make it fit
# tile 5/7/12 size is 981334 with detail 12, >500000
# Going to try keeping the sparsest 45.86% of the features to make it fit
# tile 5/7/12 size is 734568 with detail 12, >500000
# Going to try keeping the sparsest 28.09% of the features to make it fit
# tile 5/8/11 size is 1390124 with detail 12, >500000
# Going to try keeping the sparsest 32.37% of the features to make it fit
# tile 5/7/12 size is 548619 with detail 12, >500000
# Going to try keeping the sparsest 23.04% of the features to make it fit
# tile 5/8/11 size is 838655 with detail 12, >500000
# Going to try keeping the sparsest 17.37% of the features to make it fit
# tile 5/8/11 size is 552234 with detail 12, >500000
# Going to try keeping the sparsest 14.15% of the features to make it fit
# tile 5/6/11 size is 1668466 with detail 12, >500000
# Going to try keeping the sparsest 26.97% of the features to make it fit
# tile 5/6/12 size is 1444251 with detail 12, >500000
# Going to try keeping the sparsest 31.16% of the features to make it fit
# tile 5/5/11 size is 1125437 with detail 12, >500000
# tile 5/5/12 size is 1146587 with detail 12, >500000
# Going to try keeping the sparsest 39.98% of the features to make it fit
# Going to try keeping the sparsest 39.25% of the features to make it fit
# tile 5/7/11 size is 2422251 with detail 12, >500000
# Going to try keeping the sparsest 18.58% of the features to make it fit
# tile 5/6/11 size is 710059 with detail 12, >500000
# Going to try keeping the sparsest 17.09% of the features to make it fit
# tile 5/5/12 size is 942796 with detail 12, >500000
# Going to try keeping the sparsest 18.73% of the features to make it fit
# tile 5/5/11 size is 924964 with detail 12, >500000
# Going to try keeping the sparsest 19.45% of the features to make it fit
# tile 5/6/11 size is 507651 with detail 12, >500000
# Going to try keeping the sparsest 15.15% of the features to make it fit
# tile 5/6/12 size is 910496 with detail 12, >500000
# Going to try keeping the sparsest 15.40% of the features to make it fit
# tile 5/7/11 size is 797471 with detail 12, >500000
# Going to try keeping the sparsest 10.48% of the features to make it fit
# tile 5/8/12 size is 2295855 with detail 12, >500000
# Going to try keeping the sparsest 19.60% of the features to make it fit
# tile 5/5/12 size is 684685 with detail 12, >500000
# Going to try keeping the sparsest 12.31% of the features to make it fit
# tile 5/7/11 size is 517082 with detail 12, >500000
# Going to try keeping the sparsest 9.12% of the features to make it fit
# tile 5/5/11 size is 688336 with detail 12, >500000
# Going to try keeping the sparsest 12.72% of the features to make it fit
# tile 5/6/12 size is 625615 with detail 12, >500000
# Going to try keeping the sparsest 11.08% of the features to make it fit
# tile 5/5/12 size is 537196 with detail 12, >500000
# Going to try keeping the sparsest 10.31% of the features to make it fit
# tile 5/8/12 size is 883050 with detail 12, >500000
# Going to try keeping the sparsest 9.99% of the features to make it fit
# tile 5/5/11 size is 552634 with detail 12, >500000
# Going to try keeping the sparsest 10.36% of the features to make it fit
# tile 5/6/12 size is 535393 with detail 12, >500000
# Going to try keeping the sparsest 9.31% of the features to make it fit
# tile 5/9/11 size is 4235267 with detail 12, >500000
# Going to try keeping the sparsest 10.63% of the features to make it fit
# tile 5/8/12 size is 527493 with detail 12, >500000
# Going to try keeping the sparsest 8.52% of the features to make it fit
# tile 5/9/11 size is 971320 with detail 12, >500000
# Going to try keeping the sparsest 4.92% of the features to make it fit
# tile 5/9/12 size is 4410942 with detail 12, >500000
# Going to try keeping the sparsest 10.20% of the features to make it fit
# tile 5/9/11 size is 507403 with detail 12, >500000
# Going to try keeping the sparsest 4.37% of the features to make it fit
# tile 5/9/12 size is 1119114 with detail 12, >500000
# Going to try keeping the sparsest 4.10% of the features to make it fit
# tile 5/9/12 size is 519653 with detail 12, >500000
# Going to try keeping the sparsest 3.55% of the features to make it fit
# tile 6/15/24 size is 507293 with detail 12, >500000
# Going to try keeping the sparsest 88.71% of the features to make it fit
# tile 6/13/23 size is 721912 with detail 12, >500000
# Going to try keeping the sparsest 62.33% of the features to make it fit
# tile 6/14/23 size is 623488 with detail 12, >500000
# Going to try keeping the sparsest 72.17% of the features to make it fit
# tile 6/17/23 size is 686567 with detail 12, >500000
# Going to try keeping the sparsest 65.54% of the features to make it fit
# tile 6/16/24 size is 691077 with detail 12, >500000
# Going to try keeping the sparsest 65.12% of the features to make it fit
# tile 6/13/23 size is 511760 with detail 12, >500000
# Going to try keeping the sparsest 54.81% of the features to make it fit
# tile 6/14/22 size is 1032650 with detail 12, >500000
# Going to try keeping the sparsest 43.58% of the features to make it fit
# tile 6/16/25 size is 559033 with detail 12, >500000
# Going to try keeping the sparsest 80.50% of the features to make it fit
# tile 6/12/24 size is 652361 with detail 12, >500000
# Going to try keeping the sparsest 68.98% of the features to make it fit
# tile 6/15/23 size is 902301 with detail 12, >500000
# Going to try keeping the sparsest 49.87% of the features to make it fit
# tile 6/16/23 size is 1044659 with detail 12, >500000
# Going to try keeping the sparsest 43.08% of the features to make it fit
# tile 6/12/23 size is 764125 with detail 12, >500000
# Going to try keeping the sparsest 58.89% of the features to make it fit
# tile 6/13/24 size is 834868 with detail 12, >500000
# Going to try keeping the sparsest 53.90% of the features to make it fit
# tile 6/17/23 size is 572146 with detail 12, >500000
# Going to try keeping the sparsest 51.55% of the features to make it fit
# tile 6/10/24 size is 791784 with detail 12, >500000
# Going to try keeping the sparsest 56.83% of the features to make it fit
# tile 6/10/22 size is 666168 with detail 12, >500000
# Going to try keeping the sparsest 67.55% of the features to make it fit
# tile 6/11/25 size is 522400 with detail 12, >500000
# Going to try keeping the sparsest 86.14% of the features to make it fit
# tile 6/15/22 size is 763750 with detail 12, >500000
# Going to try keeping the sparsest 58.92% of the features to make it fit
# tile 6/16/24 size is 549844 with detail 12, >500000
# Going to try keeping the sparsest 53.29% of the features to make it fit
# tile 6/15/23 size is 605357 with detail 12, >500000
# Going to try keeping the sparsest 37.07% of the features to make it fit
# tile 6/16/25 size is 514960 with detail 12, >500000
# Going to try keeping the sparsest 70.34% of the features to make it fit
# tile 6/17/24 size is 1121846 with detail 12, >500000
# Going to try keeping the sparsest 40.11% of the features to make it fit
# tile 6/16/23 size is 674066 with detail 12, >500000
# Going to try keeping the sparsest 28.76% of the features to make it fit
# tile 6/13/24 size is 611337 with detail 12, >500000
# Going to try keeping the sparsest 39.68% of the features to make it fit
# tile 6/12/24 size is 538856 with detail 12, >500000
# Going to try keeping the sparsest 57.61% of the features to make it fit
# tile 6/12/23 size is 532248 with detail 12, >500000
# Going to try keeping the sparsest 49.79% of the features to make it fit
# tile 6/10/22 size is 592092 with detail 12, >500000
# Going to try keeping the sparsest 51.34% of the features to make it fit
# tile 6/10/24 size is 658277 with detail 12, >500000
# Going to try keeping the sparsest 38.85% of the features to make it fit
# tile 6/16/23 size is 501002 with detail 12, >500000
# Going to try keeping the sparsest 25.83% of the features to make it fit
# tile 6/11/25 size is 515595 with detail 12, >500000
# Going to try keeping the sparsest 75.18% of the features to make it fit
# tile 6/13/24 size is 500143 with detail 12, >500000
# Going to try keeping the sparsest 35.70% of the features to make it fit
# tile 6/17/25 size is 1030981 with detail 12, >500000
# Going to try keeping the sparsest 43.65% of the features to make it fit
# tile 6/15/22 size is 592635 with detail 12, >500000
# Going to try keeping the sparsest 44.74% of the features to make it fit
# tile 6/17/24 size is 664354 with detail 12, >500000
# Going to try keeping the sparsest 27.17% of the features to make it fit
# tile 6/10/22 size is 521620 with detail 12, >500000
# Going to try keeping the sparsest 44.29% of the features to make it fit
# tile 6/10/24 size is 541582 with detail 12, >500000
# Going to try keeping the sparsest 32.28% of the features to make it fit
# tile 6/11/25 size is 506105 with detail 12, >500000
# Going to try keeping the sparsest 66.85% of the features to make it fit
# tile 6/17/24 size is 504104 with detail 12, >500000
# Going to try keeping the sparsest 24.25% of the features to make it fit
# tile 6/18/23 size is 2177674 with detail 12, >500000
# Going to try keeping the sparsest 20.66% of the features to make it fit
# tile 6/15/22 size is 518974 with detail 12, >500000
# Going to try keeping the sparsest 38.79% of the features to make it fit
# tile 6/17/25 size is 650273 with detail 12, >500000
# Going to try keeping the sparsest 30.20% of the features to make it fit
# tile 6/18/23 size is 743633 with detail 12, >500000
# Going to try keeping the sparsest 12.50% of the features to make it fit
# tile 6/19/23 size is 4449728 with detail 12, >500000
# Going to try keeping the sparsest 10.11% of the features to make it fit
# tile 6/19/23 size is 849922 with detail 12, >500000
# Going to try keeping the sparsest 5.35% of the features to make it fit
# tile 6/18/24 size is 5946884 with detail 12, >500000
# Going to try keeping the sparsest 7.57% of the features to make it fit
# tile 6/18/24 size is 903886 with detail 12, >500000
# Going to try keeping the sparsest 3.77% of the features to make it fit
# tile 7/30/46 size is 537181 with detail 12, >500000
# Going to try keeping the sparsest 83.77% of the features to make it fit
# tile 7/39/46 size is 519635 with detail 12, >500000
# Going to try keeping the sparsest 86.60% of the features to make it fit
# tile 7/32/47 size is 699076 with detail 12, >500000
# Going to try keeping the sparsest 64.37% of the features to make it fit
# tile 7/20/49 size is 600561 with detail 12, >500000
# Going to try keeping the sparsest 74.93% of the features to make it fit
# tile 7/37/46 size is 616600 with detail 12, >500000
# Going to try keeping the sparsest 72.98% of the features to make it fit
# tile 7/26/48 size is 725847 with detail 12, >500000
# Going to try keeping the sparsest 62.00% of the features to make it fit
# tile 7/35/50 size is 514383 with detail 12, >500000
# Going to try keeping the sparsest 87.48% of the features to make it fit
# tile 7/22/51 size is 589074 with detail 12, >500000
# Going to try keeping the sparsest 76.39% of the features to make it fit
# tile 7/32/47 size is 528030 with detail 12, >500000
# Going to try keeping the sparsest 54.86% of the features to make it fit
# tile 7/20/49 size is 513949 with detail 12, >500000
# Going to try keeping the sparsest 65.61% of the features to make it fit
# tile 7/37/46 size is 515613 with detail 12, >500000
# Going to try keeping the sparsest 63.69% of the features to make it fit
# tile 7/26/48 size is 535332 with detail 12, >500000
# Going to try keeping the sparsest 52.11% of the features to make it fit
# tile 7/22/51 size is 550008 with detail 12, >500000
# Going to try keeping the sparsest 62.50% of the features to make it fit
# tile 7/36/49 size is 1178782 with detail 12, >500000
# Going to try keeping the sparsest 38.17% of the features to make it fit
# tile 7/37/47 size is 1607519 with detail 12, >500000
# Going to try keeping the sparsest 27.99% of the features to make it fit
# tile 7/38/46 size is 1610219 with detail 12, >500000
# Going to try keeping the sparsest 27.95% of the features to make it fit
# tile 7/22/51 size is 505698 with detail 12, >500000
# Going to try keeping the sparsest 55.62% of the features to make it fit
# tile 7/37/47 size is 623484 with detail 12, >500000
# Going to try keeping the sparsest 20.20% of the features to make it fit
# tile 7/38/46 size is 628046 with detail 12, >500000
# Going to try keeping the sparsest 20.02% of the features to make it fit
# tile 7/36/49 size is 731608 with detail 12, >500000
# Going to try keeping the sparsest 23.48% of the features to make it fit
# tile 7/36/49 size is 500691 with detail 12, >500000
# Going to try keeping the sparsest 21.10% of the features to make it fit
# tile 7/36/48 size is 2964980 with detail 12, >500000
# Going to try keeping the sparsest 15.18% of the features to make it fit
# tile 7/38/47 size is 3691335 with detail 12, >500000
# Going to try keeping the sparsest 12.19% of the features to make it fit
# tile 7/37/48 size is 3542286 with detail 12, >500000
# Going to try keeping the sparsest 12.70% of the features to make it fit
# tile 7/38/47 size is 670767 with detail 12, >500000
# Going to try keeping the sparsest 8.18% of the features to make it fit
# tile 7/36/48 size is 829749 with detail 12, >500000
# Going to try keeping the sparsest 8.23% of the features to make it fit
# tile 7/37/48 size is 687866 with detail 12, >500000
# Going to try keeping the sparsest 8.31% of the features to make it fit
# tile 8/77/93 size is 600360 with detail 12, >500000
# Going to try keeping the sparsest 74.96% of the features to make it fit
# tile 8/76/93 size is 555144 with detail 12, >500000
# Going to try keeping the sparsest 81.06% of the features to make it fit
# tile 8/72/97 size is 606645 with detail 12, >500000
# Going to try keeping the sparsest 74.18% of the features to make it fit
# tile 8/76/92 size is 525942 with detail 12, >500000
# Going to try keeping the sparsest 85.56% of the features to make it fit
# tile 8/75/96 size is 773975 with detail 12, >500000
# Going to try keeping the sparsest 58.14% of the features to make it fit
# tile 8/75/95 size is 893658 with detail 12, >500000
# Going to try keeping the sparsest 50.35% of the features to make it fit
# tile 8/73/98 size is 762092 with detail 12, >500000
# Going to try keeping the sparsest 59.05% of the features to make it fit
# tile 8/72/97 size is 510554 with detail 12, >500000
# Going to try keeping the sparsest 65.38% of the features to make it fit
# tile 8/77/95 size is 879970 with detail 12, >500000
# Going to try keeping the sparsest 51.14% of the features to make it fit
# tile 8/76/95 size is 1005833 with detail 12, >500000
# Going to try keeping the sparsest 44.74% of the features to make it fit
# tile 8/76/94 size is 1222258 with detail 12, >500000
# Going to try keeping the sparsest 36.82% of the features to make it fit
# tile 8/73/96 size is 964535 with detail 12, >500000
# Going to try keeping the sparsest 46.65% of the features to make it fit
# tile 8/76/95 size is 519919 with detail 12, >500000
# Going to try keeping the sparsest 38.72% of the features to make it fit
# tile 8/75/95 size is 531290 with detail 12, >500000
# Going to try keeping the sparsest 42.65% of the features to make it fit
# tile 8/75/96 size is 561637 with detail 12, >500000
# Going to try keeping the sparsest 46.58% of the features to make it fit
# tile 8/77/95 size is 537425 with detail 12, >500000
# Going to try keeping the sparsest 42.82% of the features to make it fit
# tile 8/73/98 size is 600566 with detail 12, >500000
# Going to try keeping the sparsest 44.24% of the features to make it fit
# tile 8/76/94 size is 542836 with detail 12, >500000
# Going to try keeping the sparsest 30.52% of the features to make it fit
# tile 8/73/96 size is 540237 with detail 12, >500000
# Going to try keeping the sparsest 38.86% of the features to make it fit
# tile 8/74/97 size is 1327067 with detail 12, >500000
# Going to try keeping the sparsest 33.91% of the features to make it fit
# tile 8/77/94 size is 1465712 with detail 12, >500000
# Going to try keeping the sparsest 30.70% of the features to make it fit
# tile 8/77/94 size is 561694 with detail 12, >500000
# Going to try keeping the sparsest 24.60% of the features to make it fit
# tile 8/74/97 size is 586391 with detail 12, >500000
# Going to try keeping the sparsest 26.02% of the features to make it fit
# tile 8/73/97 size is 2020012 with detail 12, >500000
# Going to try keeping the sparsest 22.28% of the features to make it fit
# tile 8/74/96 size is 2204061 with detail 12, >500000
# Going to try keeping the sparsest 20.42% of the features to make it fit
# tile 8/73/97 size is 751086 with detail 12, >500000
# Going to try keeping the sparsest 13.35% of the features to make it fit
# tile 8/74/96 size is 604166 with detail 12, >500000
# Going to try keeping the sparsest 15.21% of the features to make it fit
# tile 9/146/194 size is 585635 with detail 12, >500000
# Going to try keeping the sparsest 76.84% of the features to make it fit
# tile 9/148/194 size is 650527 with detail 12, >500000
# Going to try keeping the sparsest 69.17% of the features to make it fit
# tile 9/149/193 size is 713510 with detail 12, >500000
# Going to try keeping the sparsest 63.07% of the features to make it fit
# tile 9/149/192 size is 627704 with detail 12, >500000
# Going to try keeping the sparsest 71.69% of the features to make it fit
# tile 9/154/189 size is 777663 with detail 12, >500000
# Going to try keeping the sparsest 57.87% of the features to make it fit
# tile 9/147/193 size is 527286 with detail 12, >500000
# Going to try keeping the sparsest 85.34% of the features to make it fit
# tile 9/146/196 size is 593645 with detail 12, >500000
# Going to try keeping the sparsest 75.80% of the features to make it fit
# tile 9/148/193 size is 731225 with detail 12, >500000
# Going to try keeping the sparsest 61.54% of the features to make it fit
# tile 9/147/194 size is 540534 with detail 12, >500000
# Going to try keeping the sparsest 83.25% of the features to make it fit
# tile 9/149/193 size is 506206 with detail 12, >500000
# Going to try keeping the sparsest 56.07% of the features to make it fit
# tile 9/148/194 size is 501051 with detail 12, >500000
# Going to try keeping the sparsest 62.13% of the features to make it fit
# tile 9/154/189 size is 512297 with detail 12, >500000
# Going to try keeping the sparsest 50.83% of the features to make it fit
# tile 9/146/196 size is 504509 with detail 12, >500000
# Going to try keeping the sparsest 67.61% of the features to make it fit
# tile 9/146/195 size is 1134452 with detail 12, >500000
# Going to try keeping the sparsest 39.67% of the features to make it fit
# tile 9/148/193 size is 524664 with detail 12, >500000
# Going to try keeping the sparsest 52.78% of the features to make it fit
# tile 9/146/195 size is 612463 with detail 12, >500000
# Going to try keeping the sparsest 29.14% of the features to make it fit
#   99.9%  12/855/1555
#   100.0%  12/2559/1670
# Successfully generated PMTiles file: pad-us-4.pmtiles
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5 pmtiles = to_pmtiles("pad-us-4.geojson", "pad-us-4.pmtiles")
#       7 # upload, since pmtiles cannot stream to/from buckets
# ----> 8 s3_cp('pad-us-4.pmtiles', "s3://public-biodiversity/pad-us-4/pad-us-4.pmtiles", "minio")
#      10 # Note the layer name for pmtiles: 'padus4'
#
# File ~/boettiger-lab/cng-python/src/cng/utils.py:111, in s3_cp(source, dest, profile)
#     109 bucket, object_name = match.groups()
#     110 if profile == "minio":
# --> 111     s3 = boto3.client(
#     112         "s3",
#     113         endpoint_url = "https://minio.carlboettiger.info",
#     114         aws_access_key_id = os.getenv("MINIO_KEY"),
#     115         aws_secret_access_key = os.getenv("MINIO_SECRET"),
#     116         config=Config(s3={'addressing_style': 'path'})
#     117     )
#     118     s3.upload_file(source, bucket, object_name)
#     119 if profile == "sc":
#
# File /opt/conda/lib/python3.12/site-packages/boto3/__init__.py:92, in client(*args, **kwargs)
#      86 def client(*args, **kwargs):
#      87     """
#      88     Create a low-level service client by name using the default session.
#      89
#      90     See :py:meth:`boto3.session.Session.client`.
#      91     """
# ---> 92     return _get_default_session().client(*args, **kwargs)
#
# TypeError: Session.client() missing 1 required positional argument: 'service_name'

# %%
# We can also compute intersections

"https://data.source.coop/cboettig/social-vulnerability/2022/SVI2022_US_tract.parquet"
svi = "s3://public-data/social-vulnerability/2022/SVI2022_US_tract.parquet" # faster with local

t1 = con.read_parquet(svi).select(_.ST_ABBR, _.STATE, _.FIPS, _.RPL_THEMES,  _.Shape, _.Shape_Area).rename(geom = "Shape")
t2 = con.read_parquet('s3://public-biodiversity/pad-us-4/pad-us-4.parquet').select(_.Unit_Nm, _.geom)

# %%
(t1
 .left_join(t2, t1.geom.intersects(t2.geom))
 .to_parquet("s3://public-biodiversity/pad-us-4/pad-by-tract.parquet")
)

# %%
(t1
 .right_join(t2, t1.geom.intersects(t2.geom))
 .to_parquet("s3://public-biodiversity/pad-us-4/tract-by-pad.parquet")
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# CPU times: user 18h 32min 3s, sys: 21.7 s, total: 18h 32min 24s
# Wall time: 9h 16min 32s

# %%
t1.count().execute(), t2.count().execute()
# Out:
# (84120, 414767)

# %%
# use ST number to get congressional districts
# https://www2.census.gov/geo/tiger/TIGER2024/CD/tl_2024_56_cd119.zip
