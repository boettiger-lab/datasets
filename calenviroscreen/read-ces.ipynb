# %%
from cng.utils import *
import ibis
from ibis import _
import pathlib

con = ibis.duckdb.connect(extensions = ["spatial", "h3"])
set_secrets(con)
duckdb_install_h3()

# %%
con.read_parquet("https://minio.carlboettiger.info/public-calenviroscreen/ces_2021.parquet").head().execute()
# Out:
#           Tract    ZIP  Population    CIscore   CIscoreP     Ozone  \
# 0  6.083002e+09  93454        4495  36.019653  69.162885  0.034190
# 1  6.083002e+09  93455       13173  37.030667  70.637922  0.035217
# 2  6.083002e+09  93454        2398  31.213140  61.069087  0.034190
# 3  6.083002e+09  93455        4496   6.639331   5.988401  0.036244
# 4  6.083002e+09  93455        4008  14.022852  23.121533  0.036244
#
#    Ozone_Pctl     PM2_5  PM2_5_Pctl  Diesel_PM  ...  Native_American  \
# 0   10.566273  7.567724   10.031114   0.154573  ...           0.2670
# 1   11.561917  7.624775   10.454263   0.106088  ...           0.0000
# 2   10.566273  7.548835    9.931549   0.190474  ...           0.0000
# 3   13.615432  7.660570   10.653391   0.091384  ...           0.7117
# 4   13.615432  7.663210   10.690728   0.050976  ...           1.4721
#
#    Asian_American  Pacific_Islander  Other_Multiple  Shape_Length  \
# 0          8.2091               0.0          1.3126   6999.357622
# ...
